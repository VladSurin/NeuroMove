# %%
# !pip install -U catalyst
# !pip install scikit-learn
# Out:
# Collecting catalyst
#   Downloading https://files.pythonhosted.org/packages/b7/8b/03a94e9943885ac39f11b46932ea51542812a78a901cc631d0a0348bcbd0/catalyst-20.12-py2.py3-none-any.whl (490kB)
#      |████████████████████████████████| 491kB 7.7MB/s
# Collecting tensorboardX>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/af/0c/4f41bcd45db376e6fe5c619c01100e9b7531c55791b7244815bac6eac32c/tensorboardX-2.1-py2.py3-none-any.whl (308kB)
#      |████████████████████████████████| 317kB 14.3MB/s
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from catalyst) (3.13)
# Requirement already satisfied, skipping upgrade: torch>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from catalyst) (1.7.0+cu101)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.4 in /usr/local/lib/python3.6/dist-packages (from catalyst) (1.19.4)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from catalyst) (20.8)
# Requirement already satisfied, skipping upgrade: tqdm>=4.33.0 in /usr/local/lib/python3.6/dist-packages (from catalyst) (4.41.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX>=2.1.0->catalyst) (3.12.4)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX>=2.1.0->catalyst) (1.15.0)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->catalyst) (0.16.0)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->catalyst) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->catalyst) (0.8)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->catalyst) (2.4.7)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX>=2.1.0->catalyst) (51.1.1)
# Installing collected packages: tensorboardX, catalyst
# Successfully installed catalyst-20.12 tensorboardX-2.1
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.19.4)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.0.0)

# %%
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch

import torchvision.transforms as T
import torchvision.transforms.functional as VF

import numpy as np
from numpy.random import default_rng
import os
from os import makedirs, path
from tqdm.notebook import tqdm
from os.path import join

from sklearn.model_selection import train_test_split

from PIL import Image, ImageDraw

from catalyst.dl import Runner, SupervisedRunner
from catalyst.callbacks.scheduler import SchedulerCallback
from catalyst.callbacks.early_stop import EarlyStoppingCallback
from catalyst.utils import set_global_seed, prepare_cudnn

import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42)

# %%
orig_width, orig_height = 640, 640
width, height = 640, 640

func = lambda x: x ** 4
max_x = np.pi / 2

linewidth = 4


def img_threshold(img, thresh=150):
    fn = lambda x : 255 if x > thresh else 0
    img = img.convert('L').point(fn, mode='1')
    return img


def to(values, out_min, out_max):
    in_min = values.min()
    in_max = values.max()
    return (values - in_min) * (out_max - out_min) / (in_max - in_min) + out_min


def generate_points(func, abs_value=np.pi, size=1000):
    x = np.linspace(-1, 1, size)
    y = to(func(x * abs_value), -1, 1)
    return x, y


def randomize(x, y, eps=1e-2, seed=42, random_state=None):
    if random_state is None:
        random_state = default_rng(seed)
    x = (x + random_state.uniform(-eps, eps, x.shape[0]))
    y = (y + random_state.uniform(-eps, eps, y.shape[0])) * random_state.choice([1, -1])
    return x, y


def bound_points(x, y, seed=42, random_state=None):
    if random_state is None:
        random_state = default_rng(seed)
    bound = random_state.uniform(0.3, 1.0, 2)
    x *= bound[0]
    y *= bound[1]
    return x, y


def offset_points(x, y, seed=42, random_state=None):
    if random_state is None:
        random_state = default_rng(seed)
    bound = random_state.uniform(0.3, 1.0, 2)
    offset = random_state.uniform((-1 + bound) / 2, (1 - bound) / 2)
    x += offset[0]
    y += offset[1]
    return x, y


def full_randomize(x, y, seed=42, do_randomize=True):
    if do_randomize:
        x, y = randomize(x, y, seed=seed)
    x, y = bound_points(x, y, seed=seed)
    x, y = offset_points(x, y, seed=seed)
    return x, y


def create_image(x, y, 
                 orig_size=(orig_width, orig_height),
                 size=(width, height),
                 linewidth=4, do_threshold=True):
    img = Image.new('RGB', orig_size, color='black')

    draw = ImageDraw.Draw(img)

    x = x * orig_size[0] / 2 + orig_size[0] / 2
    y = y * orig_size[1] / 2 + orig_size[1] / 2

    for xi, yi in zip(x, y):
        draw.ellipse([(xi - linewidth / 2, yi - linewidth / 2),
                      (xi + linewidth / 2, yi + linewidth / 2)],
                     fill='white')
    
    if do_threshold:
        img = img_threshold(img)
    img = img.resize(size)

    return img

seed = 42
x, y = full_randomize(*generate_points(func, abs_value=max_x), seed=seed, do_randomize=False)
create_image(x, y, linewidth=linewidth).save('test.png')

x, y = generate_points(func, abs_value=max_x)
x_rand, y_rand = full_randomize(x, y, seed=seed)
create_image(x_rand, y_rand, linewidth=linewidth).save('test2.png')

# %%
width, height = 64, 64
class DocDataset(Dataset):

    def __init__(self, functions, num_points=1000, num_anchor_points=100, 
                 width=width, height=height, size=1000, train=True):
        super().__init__()
        
        self.functions = functions
        self.num_points = num_points
        self.step = self.num_points // num_anchor_points
        self.width = width
        self.height = height
        self.size = size
        self.train = train

        self.randomize_func = randomize if self.train else lambda x, y, **kwargs: (x, y)

        self.transform = T.Compose([
                                    T.ToTensor(),
                                    ])
        
        self.imgs = []
        self.points = []
        for i in tqdm(range(size)):
            start_points = generate_points(self.functions[i % len(self.functions)],
                                           np.pi/2, self.num_points)
            start_points = self.randomize_func(*start_points, seed=i)
            start_points = full_randomize(*start_points, seed=i, do_randomize=False)
            x = create_image(*start_points, size=(self.width, self.height))
            x = self.transform(x)
            start_points = np.vstack(start_points)
            start_points = np.moveaxis(start_points.astype(np.float32), 0, -1)
            self.imgs.append(x)
            self.points.append(start_points[:-1:self.step, :])
    
    def __len__(self):
        return self.size
    
    def __getitem__(self, i):
        # start_points = generate_points(self.functions[i % len(self.functions)],
        #                                np.pi/2, self.num_points)
        # start_points = np.vstack(start_points)
        # points = self.randomize_func(*start_points, seed=i)
        # points = bound_points(*points, seed=i)
        # x = create_image(*points, size=(self.width, self.height))
        # x = self.transform(x)
        # start_points = np.moveaxis(start_points.astype(np.float32), 0, -1)
        # return {'x': x, 'targets': start_points[:-1:self.step, :]}
        return {'x': self.imgs[i], 'targets': self.points[i]}

# %%
class Model(nn.Module):
    def __init__(self, conv_drop=0.2, hid_size=128, layers=4, gru_drop=0.3, lin_drop=0.5):
        super().__init__()
        self.block1 = nn.Sequential(nn.Conv2d(1, 16, kernel_size=3, padding=1),
                                     nn.BatchNorm2d(16),
                                     nn.LeakyReLU(),
                                     nn.AdaptiveMaxPool2d((32, 32)))

        self.block2 = nn.Sequential(nn.Conv2d(16, 24, kernel_size=3, padding=1),
                                     nn.BatchNorm2d(24),
                                     nn.LeakyReLU(),
                                     nn.AdaptiveMaxPool2d((24, 24)))
        
        self.block3 = nn.Sequential(nn.Conv2d(24, 32, kernel_size=3, padding=1),
                                     nn.BatchNorm2d(32),
                                     nn.LeakyReLU(),
                                     nn.AdaptiveMaxPool2d((16, 16)))
        
        self.block4 = nn.Sequential(nn.Dropout2d(conv_drop),
                                     nn.Conv2d(32, 48, kernel_size=3, padding=1),
                                     nn.BatchNorm2d(48),
                                     nn.LeakyReLU(),
                                     nn.AdaptiveMaxPool2d((8, 8)))
        
        self.flat = nn.Flatten(2)
        self.dropout1 = nn.Dropout(lin_drop)
        self.linear1 = nn.Linear(48, 100)
        self.gru = nn.GRU(64, hid_size, num_layers=layers, batch_first=True, 
                          bidirectional=True, dropout=gru_drop)
        self.dropout2 = nn.Dropout(lin_drop)
        self.linear2 = nn.Linear(hid_size * 2, 2)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)

        x = self.flat(x)
        x = x.transpose(1, 2)
        x = self.linear1(self.dropout1(x))
        x = x.transpose(1, 2)
        x, _ = self.gru(x)
        x = self.linear2(self.dropout2(x))
        x = self.tanh(x)

        return x

model = Model()

# %%
functions = [np.sin, np.sinh, np.exp, lambda x: x ** 2, lambda x: x ** 3, np.exp2, lambda x: x ** 4]

train_dataset = DocDataset(functions, size=6000)
valid_dataset = DocDataset(functions, size=600, train=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
batch_size = 32

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size)

dataloaders = {
    "train": train_dataloader,
    "valid": valid_dataloader   
}

# %%
seed = 404
set_global_seed(seed)
prepare_cudnn(True)

# %%
epochs = 200
lr = 1e-3
criterion = nn.MSELoss(reduction='sum')
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=lr)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.7,
                                                 patience=20, min_lr=0.00001)
# scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=20, verbose=True)

# %%
model.train()
model = model.cuda()

runner = SupervisedRunner(input_key='x',
                          output_key='logits',
                          input_target_key='targets')

runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    loaders=dataloaders,
    callbacks=[
        EarlyStoppingCallback(
            patience=40,
            metric="loss",
            minimize=True,
        ),
        SchedulerCallback(reduced_metric="loss"),
    ],
    num_epochs=epochs,
    verbose=True,
    load_best_on_end=True,
    initial_seed=42,
    logdir="/content/drive/My Drive/robotics/logs"
)
# Out:
# 1/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.78it/s, loss=23.193]
# 1/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.52it/s, loss=33.868]
# [2021-01-10 13:21:16,548]
# 1/200 * Epoch 1 (_base): lr=0.0010 | momentum=0.9000
# 1/200 * Epoch 1 (train): loss=163.1489
# 1/200 * Epoch 1 (valid): loss=52.3244
# 2/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.28it/s, loss=13.223]
# 2/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.58it/s, loss=25.570]
# [2021-01-10 13:21:26,754]
# 2/200 * Epoch 2 (_base): lr=0.0010 | momentum=0.9000
# 2/200 * Epoch 2 (train): loss=42.1824
# 2/200 * Epoch 2 (valid): loss=36.3108
# 3/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.71it/s, loss=11.249]
# 3/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.62it/s, loss=16.758]
# [2021-01-10 13:21:37,265]
# 3/200 * Epoch 3 (_base): lr=0.0010 | momentum=0.9000
# 3/200 * Epoch 3 (train): loss=28.2625
# 3/200 * Epoch 3 (valid): loss=21.0530
# 4/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.81it/s, loss=11.032]
# 4/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.04it/s, loss=13.892]
# [2021-01-10 13:21:47,224]
# 4/200 * Epoch 4 (_base): lr=0.0010 | momentum=0.9000
# 4/200 * Epoch 4 (train): loss=24.0204
# 4/200 * Epoch 4 (valid): loss=18.1171
# 5/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.60it/s, loss=11.141]
# 5/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.22it/s, loss=17.298]
# [2021-01-10 13:21:57,268]
# 5/200 * Epoch 5 (_base): lr=0.0010 | momentum=0.9000
# 5/200 * Epoch 5 (train): loss=20.8748
# 5/200 * Epoch 5 (valid): loss=19.8974
# 6/200 * Epoch (train): 100% 188/188 [00:09<00:00, 20.15it/s, loss=8.745]
# 6/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.45it/s, loss=10.307]
# [2021-01-10 13:22:07,036]
# 6/200 * Epoch 6 (_base): lr=0.0010 | momentum=0.9000
# 6/200 * Epoch 6 (train): loss=19.3591
# 6/200 * Epoch 6 (valid): loss=15.0284
# 7/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.13it/s, loss=8.479]
# 7/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.09it/s, loss=8.958]
# [2021-01-10 13:22:17,331]
# 7/200 * Epoch 7 (_base): lr=0.0010 | momentum=0.9000
# 7/200 * Epoch 7 (train): loss=17.4618
# 7/200 * Epoch 7 (valid): loss=12.3824
# 8/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.02it/s, loss=7.459]
# 8/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.01it/s, loss=10.461]
# [2021-01-10 13:22:27,674]
# 8/200 * Epoch 8 (_base): lr=0.0010 | momentum=0.9000
# 8/200 * Epoch 8 (train): loss=16.5507
# 8/200 * Epoch 8 (valid): loss=14.2544
# 9/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.20it/s, loss=6.689]
# 9/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.63it/s, loss=10.955]
# [2021-01-10 13:22:37,942]
# 9/200 * Epoch 9 (_base): lr=0.0010 | momentum=0.9000
# 9/200 * Epoch 9 (train): loss=16.8079
# 9/200 * Epoch 9 (valid): loss=13.4429
# 10/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.33it/s, loss=7.318]
# 10/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.15it/s, loss=8.369]
# [2021-01-10 13:22:48,139]
# 10/200 * Epoch 10 (_base): lr=0.0010 | momentum=0.9000
# 10/200 * Epoch 10 (train): loss=15.7524
# 10/200 * Epoch 10 (valid): loss=10.6226
# 11/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.01it/s, loss=6.210]
# 11/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.72it/s, loss=7.527]
# [2021-01-10 13:22:58,557]
# 11/200 * Epoch 11 (_base): lr=0.0010 | momentum=0.9000
# 11/200 * Epoch 11 (train): loss=15.4025
# 11/200 * Epoch 11 (valid): loss=9.5156
# 12/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.38it/s, loss=7.634]
# 12/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.49it/s, loss=8.558]
# [2021-01-10 13:23:08,773]
# 12/200 * Epoch 12 (_base): lr=0.0010 | momentum=0.9000
# 12/200 * Epoch 12 (train): loss=14.5988
# 12/200 * Epoch 12 (valid): loss=11.2191
# 13/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.41it/s, loss=9.788]
# 13/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.96it/s, loss=9.308]
# [2021-01-10 13:23:18,927]
# 13/200 * Epoch 13 (_base): lr=0.0010 | momentum=0.9000
# 13/200 * Epoch 13 (train): loss=13.9291
# 13/200 * Epoch 13 (valid): loss=13.2953
# 14/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.28it/s, loss=7.141]
# 14/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.48it/s, loss=8.377]
# [2021-01-10 13:23:29,117]
# 14/200 * Epoch 14 (_base): lr=0.0010 | momentum=0.9000
# 14/200 * Epoch 14 (train): loss=13.8374
# 14/200 * Epoch 14 (valid): loss=12.4207
# 15/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.15it/s, loss=5.935]
# 15/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.70it/s, loss=6.785]
# [2021-01-10 13:23:39,372]
# 15/200 * Epoch 15 (_base): lr=0.0010 | momentum=0.9000
# 15/200 * Epoch 15 (train): loss=13.6164
# 15/200 * Epoch 15 (valid): loss=9.4281
# 16/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.40it/s, loss=6.337]
# 16/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.01it/s, loss=6.106]
# [2021-01-10 13:23:49,568]
# 16/200 * Epoch 16 (_base): lr=0.0010 | momentum=0.9000
# 16/200 * Epoch 16 (train): loss=13.8757
# 16/200 * Epoch 16 (valid): loss=9.2133
# 17/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.95it/s, loss=6.626]
# 17/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.85it/s, loss=8.583]
# [2021-01-10 13:23:59,952]
# 17/200 * Epoch 17 (_base): lr=0.0010 | momentum=0.9000
# 17/200 * Epoch 17 (train): loss=13.0781
# 17/200 * Epoch 17 (valid): loss=7.0094
# 18/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.74it/s, loss=6.634]
# 18/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.78it/s, loss=7.692]
# [2021-01-10 13:24:09,923]
# 18/200 * Epoch 18 (_base): lr=0.0010 | momentum=0.9000
# 18/200 * Epoch 18 (train): loss=12.6199
# 18/200 * Epoch 18 (valid): loss=12.8486
# 19/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.65it/s, loss=5.912]
# 19/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.65it/s, loss=6.104]
# [2021-01-10 13:24:19,964]
# 19/200 * Epoch 19 (_base): lr=0.0010 | momentum=0.9000
# 19/200 * Epoch 19 (train): loss=12.4109
# 19/200 * Epoch 19 (valid): loss=8.2387
# 20/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.06it/s, loss=5.095]
# 20/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.29it/s, loss=6.911]
# [2021-01-10 13:24:30,274]
# 20/200 * Epoch 20 (_base): lr=0.0010 | momentum=0.9000
# 20/200 * Epoch 20 (train): loss=12.7874
# 20/200 * Epoch 20 (valid): loss=8.6479
# 21/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.35it/s, loss=6.479]
# 21/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.09it/s, loss=5.061]
# [2021-01-10 13:24:40,427]
# 21/200 * Epoch 21 (_base): lr=0.0010 | momentum=0.9000
# 21/200 * Epoch 21 (train): loss=11.8116
# 21/200 * Epoch 21 (valid): loss=7.0734
# 22/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.35it/s, loss=7.305]
# 22/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.08it/s, loss=9.139]
# [2021-01-10 13:24:50,577]
# 22/200 * Epoch 22 (_base): lr=0.0010 | momentum=0.9000
# 22/200 * Epoch 22 (train): loss=12.2752
# 22/200 * Epoch 22 (valid): loss=9.8215
# 23/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.22it/s, loss=6.468]
# 23/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.03it/s, loss=10.524]
# [2021-01-10 13:25:00,810]
# 23/200 * Epoch 23 (_base): lr=0.0010 | momentum=0.9000
# 23/200 * Epoch 23 (train): loss=11.7793
# 23/200 * Epoch 23 (valid): loss=12.3474
# 24/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.38it/s, loss=6.609]
# 24/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.27it/s, loss=8.517]
# [2021-01-10 13:25:10,969]
# 24/200 * Epoch 24 (_base): lr=0.0010 | momentum=0.9000
# 24/200 * Epoch 24 (train): loss=11.7738
# 24/200 * Epoch 24 (valid): loss=10.2538
# 25/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.87it/s, loss=5.321]
# 25/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.73it/s, loss=4.920]
# [2021-01-10 13:25:21,407]
# 25/200 * Epoch 25 (_base): lr=0.0010 | momentum=0.9000
# 25/200 * Epoch 25 (train): loss=12.1850
# 25/200 * Epoch 25 (valid): loss=6.9489
# 26/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.69it/s, loss=5.563]
# 26/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.04it/s, loss=7.771]
# [2021-01-10 13:25:31,426]
# 26/200 * Epoch 26 (_base): lr=0.0010 | momentum=0.9000
# 26/200 * Epoch 26 (train): loss=11.8607
# 26/200 * Epoch 26 (valid): loss=10.2741
# 27/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.50it/s, loss=5.154]
# 27/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 53.38it/s, loss=4.992]
# [2021-01-10 13:25:42,029]
# 27/200 * Epoch 27 (_base): lr=0.0010 | momentum=0.9000
# 27/200 * Epoch 27 (train): loss=11.4290
# 27/200 * Epoch 27 (valid): loss=6.2751
# 28/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.14it/s, loss=5.631]
# 28/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.89it/s, loss=5.989]
# [2021-01-10 13:25:52,367]
# 28/200 * Epoch 28 (_base): lr=0.0010 | momentum=0.9000
# 28/200 * Epoch 28 (train): loss=10.8947
# 28/200 * Epoch 28 (valid): loss=7.3135
# 29/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.04it/s, loss=6.172]
# 29/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.77it/s, loss=6.405]
# [2021-01-10 13:26:02,702]
# 29/200 * Epoch 29 (_base): lr=0.0010 | momentum=0.9000
# 29/200 * Epoch 29 (train): loss=11.4408
# 29/200 * Epoch 29 (valid): loss=8.4465
# 30/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.99it/s, loss=5.751]
# 30/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.56it/s, loss=4.202]
# [2021-01-10 13:26:13,106]
# 30/200 * Epoch 30 (_base): lr=0.0010 | momentum=0.9000
# 30/200 * Epoch 30 (train): loss=11.0500
# 30/200 * Epoch 30 (valid): loss=4.9520
# 31/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.04it/s, loss=5.729]
# 31/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.09it/s, loss=5.504]
# [2021-01-10 13:26:23,446]
# 31/200 * Epoch 31 (_base): lr=0.0010 | momentum=0.9000
# 31/200 * Epoch 31 (train): loss=10.9775
# 31/200 * Epoch 31 (valid): loss=6.6322
# 32/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.49it/s, loss=6.103]
# 32/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.81it/s, loss=3.834]
# [2021-01-10 13:26:33,549]
# 32/200 * Epoch 32 (_base): lr=0.0010 | momentum=0.9000
# 32/200 * Epoch 32 (train): loss=11.2975
# 32/200 * Epoch 32 (valid): loss=5.4610
# 33/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.92it/s, loss=4.716]
# 33/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.44it/s, loss=8.688]
# [2021-01-10 13:26:43,953]
# 33/200 * Epoch 33 (_base): lr=0.0010 | momentum=0.9000
# 33/200 * Epoch 33 (train): loss=11.2618
# 33/200 * Epoch 33 (valid): loss=6.7079
# 34/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.57it/s, loss=5.030]
# 34/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.66it/s, loss=3.498]
# [2021-01-10 13:26:53,999]
# 34/200 * Epoch 34 (_base): lr=0.0010 | momentum=0.9000
# 34/200 * Epoch 34 (train): loss=10.8219
# 34/200 * Epoch 34 (valid): loss=5.3430
# 35/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.65it/s, loss=5.430]
# 35/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.67it/s, loss=7.557]
# [2021-01-10 13:27:04,019]
# 35/200 * Epoch 35 (_base): lr=0.0010 | momentum=0.9000
# 35/200 * Epoch 35 (train): loss=10.5212
# 35/200 * Epoch 35 (valid): loss=9.3099
# 36/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.37it/s, loss=5.924]
# 36/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.45it/s, loss=3.877]
# [2021-01-10 13:27:14,190]
# 36/200 * Epoch 36 (_base): lr=0.0010 | momentum=0.9000
# 36/200 * Epoch 36 (train): loss=10.6877
# 36/200 * Epoch 36 (valid): loss=5.3959
# 37/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.83it/s, loss=5.589]
# 37/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.84it/s, loss=4.417]
# [2021-01-10 13:27:24,620]
# 37/200 * Epoch 37 (_base): lr=0.0010 | momentum=0.9000
# 37/200 * Epoch 37 (train): loss=10.4289
# 37/200 * Epoch 37 (valid): loss=5.0437
# 38/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.32it/s, loss=5.392]
# 38/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.41it/s, loss=4.321]
# [2021-01-10 13:27:34,808]
# 38/200 * Epoch 38 (_base): lr=0.0010 | momentum=0.9000
# 38/200 * Epoch 38 (train): loss=10.2007
# 38/200 * Epoch 38 (valid): loss=5.7182
# 39/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.05it/s, loss=5.278]
# 39/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.96it/s, loss=3.561]
# [2021-01-10 13:27:45,163]
# 39/200 * Epoch 39 (_base): lr=0.0010 | momentum=0.9000
# 39/200 * Epoch 39 (train): loss=10.0382
# 39/200 * Epoch 39 (valid): loss=5.7596
# 40/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.25it/s, loss=4.459]
# 40/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.85it/s, loss=6.671]
# [2021-01-10 13:27:55,390]
# 40/200 * Epoch 40 (_base): lr=0.0010 | momentum=0.9000
# 40/200 * Epoch 40 (train): loss=10.2392
# 40/200 * Epoch 40 (valid): loss=8.7114
# 41/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.45it/s, loss=5.859]
# 41/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.01it/s, loss=4.819]
# [2021-01-10 13:28:05,512]
# 41/200 * Epoch 41 (_base): lr=0.0010 | momentum=0.9000
# 41/200 * Epoch 41 (train): loss=10.0065
# 41/200 * Epoch 41 (valid): loss=7.0029
# 42/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.97it/s, loss=4.565]
# 42/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.60it/s, loss=4.428]
# [2021-01-10 13:28:15,884]
# 42/200 * Epoch 42 (_base): lr=0.0010 | momentum=0.9000
# 42/200 * Epoch 42 (train): loss=10.4724
# 42/200 * Epoch 42 (valid): loss=6.3550
# 43/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.80it/s, loss=4.419]
# 43/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.63it/s, loss=5.341]
# [2021-01-10 13:28:26,340]
# 43/200 * Epoch 43 (_base): lr=0.0010 | momentum=0.9000
# 43/200 * Epoch 43 (train): loss=9.8384
# 43/200 * Epoch 43 (valid): loss=6.0607
# 44/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.23it/s, loss=4.499]
# 44/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.25it/s, loss=3.599]
# [2021-01-10 13:28:36,575]
# 44/200 * Epoch 44 (_base): lr=0.0010 | momentum=0.9000
# 44/200 * Epoch 44 (train): loss=9.9195
# 44/200 * Epoch 44 (valid): loss=5.4168
# 45/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.73it/s, loss=4.800]
# 45/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.28it/s, loss=4.508]
# [2021-01-10 13:28:47,083]
# 45/200 * Epoch 45 (_base): lr=0.0010 | momentum=0.9000
# 45/200 * Epoch 45 (train): loss=9.5260
# 45/200 * Epoch 45 (valid): loss=5.0076
# 46/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.14it/s, loss=5.321]
# 46/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 52.35it/s, loss=3.888]
# [2021-01-10 13:28:57,349]
# 46/200 * Epoch 46 (_base): lr=0.0010 | momentum=0.9000
# 46/200 * Epoch 46 (train): loss=9.4974
# 46/200 * Epoch 46 (valid): loss=5.6853
# 47/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.09it/s, loss=5.264]
# 47/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.52it/s, loss=4.761]
# [2021-01-10 13:29:07,663]
# 47/200 * Epoch 47 (_base): lr=0.0010 | momentum=0.9000
# 47/200 * Epoch 47 (train): loss=10.0278
# 47/200 * Epoch 47 (valid): loss=6.6735
# 48/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.13it/s, loss=4.964]
# 48/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.11it/s, loss=4.172]
# [2021-01-10 13:29:17,950]
# 48/200 * Epoch 48 (_base): lr=0.0010 | momentum=0.9000
# 48/200 * Epoch 48 (train): loss=12.8291
# 48/200 * Epoch 48 (valid): loss=5.4381
# 49/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.35it/s, loss=4.689]
# 49/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.23it/s, loss=4.334]
# [2021-01-10 13:29:28,145]
# 49/200 * Epoch 49 (_base): lr=0.0010 | momentum=0.9000
# 49/200 * Epoch 49 (train): loss=9.6549
# 49/200 * Epoch 49 (valid): loss=5.5028
# 50/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.18it/s, loss=4.731]
# 50/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.05it/s, loss=4.383]
# [2021-01-10 13:29:38,460]
# 50/200 * Epoch 50 (_base): lr=0.0010 | momentum=0.9000
# 50/200 * Epoch 50 (train): loss=9.5835
# 50/200 * Epoch 50 (valid): loss=5.9396
# 51/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.78it/s, loss=4.023]
# 51/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.21it/s, loss=2.740]
# [2021-01-10 13:29:48,953]
# 51/200 * Epoch 51 (_base): lr=0.0010 | momentum=0.9000
# 51/200 * Epoch 51 (train): loss=9.5195
# 51/200 * Epoch 51 (valid): loss=4.2201
# 52/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.95it/s, loss=5.034]
# 52/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.68it/s, loss=3.315]
# [2021-01-10 13:29:59,340]
# 52/200 * Epoch 52 (_base): lr=0.0010 | momentum=0.9000
# 52/200 * Epoch 52 (train): loss=9.4011
# 52/200 * Epoch 52 (valid): loss=5.1470
# 53/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.21it/s, loss=4.404]
# 53/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.32it/s, loss=3.948]
# [2021-01-10 13:30:10,116]
# 53/200 * Epoch 53 (_base): lr=0.0010 | momentum=0.9000
# 53/200 * Epoch 53 (train): loss=9.4967
# 53/200 * Epoch 53 (valid): loss=5.4478
# 54/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.61it/s, loss=5.131]
# 54/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.64it/s, loss=4.299]
# [2021-01-10 13:30:20,685]
# 54/200 * Epoch 54 (_base): lr=0.0010 | momentum=0.9000
# 54/200 * Epoch 54 (train): loss=9.6973
# 54/200 * Epoch 54 (valid): loss=6.6938
# 55/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.99it/s, loss=4.790]
# 55/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.67it/s, loss=2.986]
# [2021-01-10 13:30:31,083]
# 55/200 * Epoch 55 (_base): lr=0.0010 | momentum=0.9000
# 55/200 * Epoch 55 (train): loss=9.4813
# 55/200 * Epoch 55 (valid): loss=4.2802
# 56/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.58it/s, loss=4.072]
# 56/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.13it/s, loss=4.519]
# [2021-01-10 13:30:41,709]
# 56/200 * Epoch 56 (_base): lr=0.0010 | momentum=0.9000
# 56/200 * Epoch 56 (train): loss=9.1828
# 56/200 * Epoch 56 (valid): loss=4.8656
# 57/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.76it/s, loss=3.941]
# 57/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.06it/s, loss=3.512]
# [2021-01-10 13:30:52,184]
# 57/200 * Epoch 57 (_base): lr=0.0010 | momentum=0.9000
# 57/200 * Epoch 57 (train): loss=9.1537
# 57/200 * Epoch 57 (valid): loss=5.2012
# 58/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.39it/s, loss=4.549]
# 58/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.91it/s, loss=3.894]
# [2021-01-10 13:31:02,343]
# 58/200 * Epoch 58 (_base): lr=0.0010 | momentum=0.9000
# 58/200 * Epoch 58 (train): loss=9.1190
# 58/200 * Epoch 58 (valid): loss=4.6264
# 59/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.30it/s, loss=4.347]
# 59/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.64it/s, loss=4.699]
# [2021-01-10 13:31:12,531]
# 59/200 * Epoch 59 (_base): lr=0.0010 | momentum=0.9000
# 59/200 * Epoch 59 (train): loss=9.0792
# 59/200 * Epoch 59 (valid): loss=5.8679
# 60/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.92it/s, loss=4.948]
# 60/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.86it/s, loss=5.538]
# [2021-01-10 13:31:22,920]
# 60/200 * Epoch 60 (_base): lr=0.0010 | momentum=0.9000
# 60/200 * Epoch 60 (train): loss=9.0499
# 60/200 * Epoch 60 (valid): loss=6.1946
# 61/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.22it/s, loss=4.290]
# 61/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.24it/s, loss=3.259]
# [2021-01-10 13:31:33,163]
# 61/200 * Epoch 61 (_base): lr=0.0010 | momentum=0.9000
# 61/200 * Epoch 61 (train): loss=9.0106
# 61/200 * Epoch 61 (valid): loss=4.9312
# 62/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.87it/s, loss=4.546]
# 62/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.80it/s, loss=3.341]
# [2021-01-10 13:31:43,592]
# 62/200 * Epoch 62 (_base): lr=0.0010 | momentum=0.9000
# 62/200 * Epoch 62 (train): loss=9.0607
# 62/200 * Epoch 62 (valid): loss=5.1192
# 63/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.72it/s, loss=4.582]
# 63/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.46it/s, loss=4.322]
# [2021-01-10 13:31:54,094]
# 63/200 * Epoch 63 (_base): lr=0.0010 | momentum=0.9000
# 63/200 * Epoch 63 (train): loss=9.1437
# 63/200 * Epoch 63 (valid): loss=6.8774
# 64/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.21it/s, loss=4.814]
# 64/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.36it/s, loss=3.701]
# [2021-01-10 13:32:04,399]
# 64/200 * Epoch 64 (_base): lr=0.0010 | momentum=0.9000
# 64/200 * Epoch 64 (train): loss=10.2825
# 64/200 * Epoch 64 (valid): loss=4.7915
# 65/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.10it/s, loss=4.619]
# 65/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.46it/s, loss=5.397]
# [2021-01-10 13:32:15,260]
# 65/200 * Epoch 65 (_base): lr=0.0010 | momentum=0.9000
# 65/200 * Epoch 65 (train): loss=9.1076
# 65/200 * Epoch 65 (valid): loss=6.1275
# 66/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.81it/s, loss=4.012]
# 66/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.16it/s, loss=4.959]
# [2021-01-10 13:32:26,280]
# 66/200 * Epoch 66 (_base): lr=0.0010 | momentum=0.9000
# 66/200 * Epoch 66 (train): loss=9.7779
# 66/200 * Epoch 66 (valid): loss=7.0225
# 67/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.33it/s, loss=4.304]
# 67/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.04it/s, loss=4.098]
# [2021-01-10 13:32:36,457]
# 67/200 * Epoch 67 (_base): lr=0.0010 | momentum=0.9000
# 67/200 * Epoch 67 (train): loss=8.9447
# 67/200 * Epoch 67 (valid): loss=4.4759
# 68/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.72it/s, loss=4.447]
# 68/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.22it/s, loss=3.094]
# [2021-01-10 13:32:47,017]
# 68/200 * Epoch 68 (_base): lr=0.0010 | momentum=0.9000
# 68/200 * Epoch 68 (train): loss=8.7057
# 68/200 * Epoch 68 (valid): loss=3.9999
# 69/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.61it/s, loss=4.067]
# 69/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.90it/s, loss=3.438]
# [2021-01-10 13:32:57,622]
# 69/200 * Epoch 69 (_base): lr=0.0010 | momentum=0.9000
# 69/200 * Epoch 69 (train): loss=9.0688
# 69/200 * Epoch 69 (valid): loss=4.7218
# 70/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.47it/s, loss=4.405]
# 70/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.86it/s, loss=3.596]
# [2021-01-10 13:33:08,251]
# 70/200 * Epoch 70 (_base): lr=0.0010 | momentum=0.9000
# 70/200 * Epoch 70 (train): loss=8.4271
# 70/200 * Epoch 70 (valid): loss=4.2145
# 71/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.80it/s, loss=4.853]
# 71/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.63it/s, loss=3.930]
# [2021-01-10 13:33:18,704]
# 71/200 * Epoch 71 (_base): lr=0.0010 | momentum=0.9000
# 71/200 * Epoch 71 (train): loss=9.0666
# 71/200 * Epoch 71 (valid): loss=4.7444
# 72/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.84it/s, loss=4.782]
# 72/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.84it/s, loss=2.932]
# [2021-01-10 13:33:29,173]
# 72/200 * Epoch 72 (_base): lr=0.0010 | momentum=0.9000
# 72/200 * Epoch 72 (train): loss=8.8261
# 72/200 * Epoch 72 (valid): loss=4.2964
# 73/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.07it/s, loss=4.768]
# 73/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.90it/s, loss=3.573]
# [2021-01-10 13:33:39,492]
# 73/200 * Epoch 73 (_base): lr=0.0010 | momentum=0.9000
# 73/200 * Epoch 73 (train): loss=8.7696
# 73/200 * Epoch 73 (valid): loss=4.5329
# 74/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.34it/s, loss=3.996]
# 74/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.02it/s, loss=2.667]
# [2021-01-10 13:33:49,667]
# 74/200 * Epoch 74 (_base): lr=0.0010 | momentum=0.9000
# 74/200 * Epoch 74 (train): loss=8.5575
# 74/200 * Epoch 74 (valid): loss=4.4401
# 75/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.00it/s, loss=5.381]
# 75/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.14it/s, loss=3.080]
# [2021-01-10 13:34:00,043]
# 75/200 * Epoch 75 (_base): lr=0.0010 | momentum=0.9000
# 75/200 * Epoch 75 (train): loss=8.5705
# 75/200 * Epoch 75 (valid): loss=4.6243
# 76/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.72it/s, loss=4.922]
# 76/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.31it/s, loss=2.708]
# [2021-01-10 13:34:10,549]
# 76/200 * Epoch 76 (_base): lr=0.0010 | momentum=0.9000
# 76/200 * Epoch 76 (train): loss=8.7395
# 76/200 * Epoch 76 (valid): loss=3.5485
# 77/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.91it/s, loss=4.177]
# 77/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.28it/s, loss=2.743]
# [2021-01-10 13:34:21,002]
# 77/200 * Epoch 77 (_base): lr=0.0010 | momentum=0.9000
# 77/200 * Epoch 77 (train): loss=8.5040
# 77/200 * Epoch 77 (valid): loss=4.2958
# 78/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.82it/s, loss=3.872]
# 78/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.28it/s, loss=5.519]
# [2021-01-10 13:34:31,468]
# 78/200 * Epoch 78 (_base): lr=0.0010 | momentum=0.9000
# 78/200 * Epoch 78 (train): loss=8.2077
# 78/200 * Epoch 78 (valid): loss=6.4056
# 79/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.08it/s, loss=4.387]
# 79/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 51.00it/s, loss=3.956]
# [2021-01-10 13:34:41,776]
# 79/200 * Epoch 79 (_base): lr=0.0010 | momentum=0.9000
# 79/200 * Epoch 79 (train): loss=8.3997
# 79/200 * Epoch 79 (valid): loss=5.7057
# 80/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.41it/s, loss=3.804]
# 80/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.10it/s, loss=3.557]
# [2021-01-10 13:34:51,946]
# 80/200 * Epoch 80 (_base): lr=0.0010 | momentum=0.9000
# 80/200 * Epoch 80 (train): loss=8.5052
# 80/200 * Epoch 80 (valid): loss=4.0244
# 81/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.73it/s, loss=4.150]
# 81/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.57it/s, loss=2.701]
# [2021-01-10 13:35:02,467]
# 81/200 * Epoch 81 (_base): lr=0.0010 | momentum=0.9000
# 81/200 * Epoch 81 (train): loss=8.3750
# 81/200 * Epoch 81 (valid): loss=3.9374
# 82/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.66it/s, loss=4.834]
# 82/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.15it/s, loss=2.954]
# [2021-01-10 13:35:13,002]
# 82/200 * Epoch 82 (_base): lr=0.0010 | momentum=0.9000
# 82/200 * Epoch 82 (train): loss=8.4246
# 82/200 * Epoch 82 (valid): loss=4.5993
# 83/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.35it/s, loss=3.502]
# 83/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.45it/s, loss=2.826]
# [2021-01-10 13:35:23,190]
# 83/200 * Epoch 83 (_base): lr=0.0010 | momentum=0.9000
# 83/200 * Epoch 83 (train): loss=8.2435
# 83/200 * Epoch 83 (valid): loss=3.8771
# 84/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.02it/s, loss=4.804]
# 84/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.35it/s, loss=3.625]
# [2021-01-10 13:35:33,543]
# 84/200 * Epoch 84 (_base): lr=0.0010 | momentum=0.9000
# 84/200 * Epoch 84 (train): loss=8.1223
# 84/200 * Epoch 84 (valid): loss=4.2187
# 85/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.36it/s, loss=4.314]
# 85/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.21it/s, loss=2.991]
# [2021-01-10 13:35:44,312]
# 85/200 * Epoch 85 (_base): lr=0.0010 | momentum=0.9000
# 85/200 * Epoch 85 (train): loss=8.6014
# 85/200 * Epoch 85 (valid): loss=3.9792
# 86/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.37it/s, loss=4.546]
# 86/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.25it/s, loss=2.869]
# [2021-01-10 13:35:55,052]
# 86/200 * Epoch 86 (_base): lr=0.0010 | momentum=0.9000
# 86/200 * Epoch 86 (train): loss=8.4424
# 86/200 * Epoch 86 (valid): loss=4.0754
# 87/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.02it/s, loss=3.803]
# 87/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.68it/s, loss=2.132]
# [2021-01-10 13:36:05,397]
# 87/200 * Epoch 87 (_base): lr=0.0010 | momentum=0.9000
# 87/200 * Epoch 87 (train): loss=8.0322
# 87/200 * Epoch 87 (valid): loss=3.8209
# 88/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.76it/s, loss=3.778]
# 88/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.14it/s, loss=2.323]
# [2021-01-10 13:36:15,923]
# 88/200 * Epoch 88 (_base): lr=0.0010 | momentum=0.9000
# 88/200 * Epoch 88 (train): loss=8.3500
# 88/200 * Epoch 88 (valid): loss=3.5685
# 89/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.43it/s, loss=4.458]
# 89/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.58it/s, loss=2.633]
# [2021-01-10 13:36:26,581]
# 89/200 * Epoch 89 (_base): lr=0.0010 | momentum=0.9000
# 89/200 * Epoch 89 (train): loss=7.9729
# 89/200 * Epoch 89 (valid): loss=4.4647
# 90/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.55it/s, loss=3.989]
# 90/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.56it/s, loss=2.611]
# [2021-01-10 13:36:37,186]
# 90/200 * Epoch 90 (_base): lr=0.0010 | momentum=0.9000
# 90/200 * Epoch 90 (train): loss=8.0158
# 90/200 * Epoch 90 (valid): loss=4.0444
# 91/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.60it/s, loss=3.786]
# 91/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.08it/s, loss=3.525]
# [2021-01-10 13:36:47,762]
# 91/200 * Epoch 91 (_base): lr=0.0010 | momentum=0.9000
# 91/200 * Epoch 91 (train): loss=8.2091
# 91/200 * Epoch 91 (valid): loss=5.1856
# 92/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.36it/s, loss=3.694]
# 92/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.21it/s, loss=3.390]
# [2021-01-10 13:36:57,969]
# 92/200 * Epoch 92 (_base): lr=0.0010 | momentum=0.9000
# 92/200 * Epoch 92 (train): loss=8.2078
# 92/200 * Epoch 92 (valid): loss=4.2990
# 93/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.51it/s, loss=4.123]
# 93/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.08it/s, loss=4.498]
# [2021-01-10 13:37:08,589]
# 93/200 * Epoch 93 (_base): lr=0.0010 | momentum=0.9000
# 93/200 * Epoch 93 (train): loss=7.9193
# 93/200 * Epoch 93 (valid): loss=6.9420
# 94/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.23it/s, loss=4.351]
# 94/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.52it/s, loss=3.884]
# [2021-01-10 13:37:19,367]
# 94/200 * Epoch 94 (_base): lr=0.0010 | momentum=0.9000
# 94/200 * Epoch 94 (train): loss=8.3426
# 94/200 * Epoch 94 (valid): loss=4.9136
# 95/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.02it/s, loss=4.805]
# 95/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.41it/s, loss=3.822]
# [2021-01-10 13:37:29,715]
# 95/200 * Epoch 95 (_base): lr=0.0010 | momentum=0.9000
# 95/200 * Epoch 95 (train): loss=8.1002
# 95/200 * Epoch 95 (valid): loss=4.8571
# 96/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.63it/s, loss=5.570]
# 96/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.96it/s, loss=3.551]
# [2021-01-10 13:37:40,266]
# 96/200 * Epoch 96 (_base): lr=0.0010 | momentum=0.9000
# 96/200 * Epoch 96 (train): loss=8.2338
# 96/200 * Epoch 96 (valid): loss=5.2922
# 97/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.62it/s, loss=3.562]
# 97/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.48it/s, loss=2.600]
# [2021-01-10 13:37:50,850]
# 97/200 * Epoch 97 (_base): lr=0.0007 | momentum=0.9000
# 97/200 * Epoch 97 (train): loss=8.9582
# 97/200 * Epoch 97 (valid): loss=3.9820
# 98/200 * Epoch (train): 100% 188/188 [00:09<00:00, 19.06it/s, loss=4.004]
# 98/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.12it/s, loss=2.016]
# [2021-01-10 13:38:01,253]
# 98/200 * Epoch 98 (_base): lr=0.0007 | momentum=0.9000
# 98/200 * Epoch 98 (train): loss=7.5059
# 98/200 * Epoch 98 (valid): loss=3.1314
# 99/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.41it/s, loss=3.635]
# 99/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.34it/s, loss=2.005]
# [2021-01-10 13:38:11,973]
# 99/200 * Epoch 99 (_base): lr=0.0007 | momentum=0.9000
# 99/200 * Epoch 99 (train): loss=7.3675
# 99/200 * Epoch 99 (valid): loss=3.4801
# 100/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.22it/s, loss=3.564]
# 100/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.69it/s, loss=2.109]
# [2021-01-10 13:38:22,795]
# 100/200 * Epoch 100 (_base): lr=0.0007 | momentum=0.9000
# 100/200 * Epoch 100 (train): loss=7.5482
# 100/200 * Epoch 100 (valid): loss=3.0796
# 101/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.37it/s, loss=3.864]
# 101/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 50.96it/s, loss=2.947]
# [2021-01-10 13:38:33,497]
# 101/200 * Epoch 101 (_base): lr=0.0007 | momentum=0.9000
# 101/200 * Epoch 101 (train): loss=7.4591
# 101/200 * Epoch 101 (valid): loss=4.8564
# 102/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.85it/s, loss=3.961]
# 102/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.03it/s, loss=2.043]
# [2021-01-10 13:38:44,515]
# 102/200 * Epoch 102 (_base): lr=0.0007 | momentum=0.9000
# 102/200 * Epoch 102 (train): loss=7.4825
# 102/200 * Epoch 102 (valid): loss=3.4277
# 103/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.00it/s, loss=3.564]
# 103/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.75it/s, loss=2.674]
# [2021-01-10 13:38:55,442]
# 103/200 * Epoch 103 (_base): lr=0.0007 | momentum=0.9000
# 103/200 * Epoch 103 (train): loss=7.3699
# 103/200 * Epoch 103 (valid): loss=4.2431
# 104/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.38it/s, loss=3.665]
# 104/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.94it/s, loss=2.294]
# [2021-01-10 13:39:06,148]
# 104/200 * Epoch 104 (_base): lr=0.0007 | momentum=0.9000
# 104/200 * Epoch 104 (train): loss=7.3683
# 104/200 * Epoch 104 (valid): loss=3.7350
# 105/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.90it/s, loss=3.633]
# 105/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.91it/s, loss=2.345]
# [2021-01-10 13:39:17,197]
# 105/200 * Epoch 105 (_base): lr=0.0007 | momentum=0.9000
# 105/200 * Epoch 105 (train): loss=7.3567
# 105/200 * Epoch 105 (valid): loss=3.6181
# 106/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.56it/s, loss=3.466]
# 106/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.54it/s, loss=1.859]
# [2021-01-10 13:39:27,824]
# 106/200 * Epoch 106 (_base): lr=0.0007 | momentum=0.9000
# 106/200 * Epoch 106 (train): loss=7.2948
# 106/200 * Epoch 106 (valid): loss=3.1237
# 107/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.97it/s, loss=3.914]
# 107/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.08it/s, loss=3.263]
# [2021-01-10 13:39:38,792]
# 107/200 * Epoch 107 (_base): lr=0.0007 | momentum=0.9000
# 107/200 * Epoch 107 (train): loss=7.4774
# 107/200 * Epoch 107 (valid): loss=4.1830
# 108/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.19it/s, loss=3.539]
# 108/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.85it/s, loss=1.870]
# [2021-01-10 13:39:49,618]
# 108/200 * Epoch 108 (_base): lr=0.0007 | momentum=0.9000
# 108/200 * Epoch 108 (train): loss=7.3344
# 108/200 * Epoch 108 (valid): loss=3.3416
# 109/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.68it/s, loss=3.244]
# 109/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.46it/s, loss=2.170]
# [2021-01-10 13:40:00,180]
# 109/200 * Epoch 109 (_base): lr=0.0007 | momentum=0.9000
# 109/200 * Epoch 109 (train): loss=7.3409
# 109/200 * Epoch 109 (valid): loss=3.9337
# 110/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.28it/s, loss=3.839]
# 110/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.41it/s, loss=1.799]
# [2021-01-10 13:40:10,950]
# 110/200 * Epoch 110 (_base): lr=0.0007 | momentum=0.9000
# 110/200 * Epoch 110 (train): loss=7.3222
# 110/200 * Epoch 110 (valid): loss=3.4469
# 111/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.45it/s, loss=3.630]
# 111/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.51it/s, loss=2.515]
# [2021-01-10 13:40:22,219]
# 111/200 * Epoch 111 (_base): lr=0.0007 | momentum=0.9000
# 111/200 * Epoch 111 (train): loss=7.2305
# 111/200 * Epoch 111 (valid): loss=4.0427
# 112/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.45it/s, loss=4.711]
# 112/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.65it/s, loss=2.099]
# [2021-01-10 13:40:32,939]
# 112/200 * Epoch 112 (_base): lr=0.0007 | momentum=0.9000
# 112/200 * Epoch 112 (train): loss=7.3441
# 112/200 * Epoch 112 (valid): loss=3.0951
# 113/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.64it/s, loss=3.783]
# 113/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.39it/s, loss=2.569]
# [2021-01-10 13:40:44,164]
# 113/200 * Epoch 113 (_base): lr=0.0007 | momentum=0.9000
# 113/200 * Epoch 113 (train): loss=7.5911
# 113/200 * Epoch 113 (valid): loss=3.6468
# 114/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.37it/s, loss=3.785]
# 114/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.67it/s, loss=2.004]
# [2021-01-10 13:40:55,482]
# 114/200 * Epoch 114 (_base): lr=0.0007 | momentum=0.9000
# 114/200 * Epoch 114 (train): loss=7.2795
# 114/200 * Epoch 114 (valid): loss=3.1794
# 115/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.22it/s, loss=3.509]
# 115/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.13it/s, loss=2.603]
# [2021-01-10 13:41:06,359]
# 115/200 * Epoch 115 (_base): lr=0.0007 | momentum=0.9000
# 115/200 * Epoch 115 (train): loss=7.1729
# 115/200 * Epoch 115 (valid): loss=3.4618
# 116/200 * Epoch (train): 100% 188/188 [00:09<00:00, 18.88it/s, loss=4.020]
# 116/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.00it/s, loss=2.882]
# [2021-01-10 13:41:16,832]
# 116/200 * Epoch 116 (_base): lr=0.0007 | momentum=0.9000
# 116/200 * Epoch 116 (train): loss=7.1837
# 116/200 * Epoch 116 (valid): loss=4.1571
# 117/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.33it/s, loss=3.170]
# 117/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.09it/s, loss=1.776]
# [2021-01-10 13:41:27,565]
# 117/200 * Epoch 117 (_base): lr=0.0007 | momentum=0.9000
# 117/200 * Epoch 117 (train): loss=7.1725
# 117/200 * Epoch 117 (valid): loss=2.7314
# 118/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.54it/s, loss=3.734]
# 118/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.30it/s, loss=2.100]
# [2021-01-10 13:41:38,231]
# 118/200 * Epoch 118 (_base): lr=0.0007 | momentum=0.9000
# 118/200 * Epoch 118 (train): loss=7.2265
# 118/200 * Epoch 118 (valid): loss=3.3092
# 119/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.80it/s, loss=3.700]
# 119/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.08it/s, loss=2.431]
# [2021-01-10 13:41:48,696]
# 119/200 * Epoch 119 (_base): lr=0.0007 | momentum=0.9000
# 119/200 * Epoch 119 (train): loss=7.1446
# 119/200 * Epoch 119 (valid): loss=3.4660
# 120/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.21it/s, loss=3.379]
# 120/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.59it/s, loss=3.546]
# [2021-01-10 13:41:59,498]
# 120/200 * Epoch 120 (_base): lr=0.0007 | momentum=0.9000
# 120/200 * Epoch 120 (train): loss=7.1710
# 120/200 * Epoch 120 (valid): loss=4.7424
# 121/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.18it/s, loss=3.679]
# 121/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.05it/s, loss=2.162]
# [2021-01-10 13:42:10,340]
# 121/200 * Epoch 121 (_base): lr=0.0007 | momentum=0.9000
# 121/200 * Epoch 121 (train): loss=7.3263
# 121/200 * Epoch 121 (valid): loss=2.8711
# 122/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.97it/s, loss=3.263]
# 122/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.82it/s, loss=2.558]
# [2021-01-10 13:42:21,288]
# 122/200 * Epoch 122 (_base): lr=0.0007 | momentum=0.9000
# 122/200 * Epoch 122 (train): loss=7.1200
# 122/200 * Epoch 122 (valid): loss=3.3477
# 123/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.39it/s, loss=3.763]
# 123/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.81it/s, loss=1.789]
# [2021-01-10 13:42:32,600]
# 123/200 * Epoch 123 (_base): lr=0.0007 | momentum=0.9000
# 123/200 * Epoch 123 (train): loss=7.2017
# 123/200 * Epoch 123 (valid): loss=3.2045
# 124/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.69it/s, loss=3.918]
# 124/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.28it/s, loss=2.427]
# [2021-01-10 13:42:43,714]
# 124/200 * Epoch 124 (_base): lr=0.0007 | momentum=0.9000
# 124/200 * Epoch 124 (train): loss=7.3822
# 124/200 * Epoch 124 (valid): loss=3.3556
# 125/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.48it/s, loss=3.599]
# 125/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.53it/s, loss=1.721]
# [2021-01-10 13:42:54,966]
# 125/200 * Epoch 125 (_base): lr=0.0007 | momentum=0.9000
# 125/200 * Epoch 125 (train): loss=7.1734
# 125/200 * Epoch 125 (valid): loss=2.9526
# 126/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.27it/s, loss=3.186]
# 126/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.00it/s, loss=1.872]
# [2021-01-10 13:43:05,762]
# 126/200 * Epoch 126 (_base): lr=0.0007 | momentum=0.9000
# 126/200 * Epoch 126 (train): loss=7.1135
# 126/200 * Epoch 126 (valid): loss=3.0116
# 127/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.81it/s, loss=3.850]
# 127/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 49.10it/s, loss=1.723]
# [2021-01-10 13:43:16,793]
# 127/200 * Epoch 127 (_base): lr=0.0007 | momentum=0.9000
# 127/200 * Epoch 127 (train): loss=7.2262
# 127/200 * Epoch 127 (valid): loss=2.9639
# 128/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.30it/s, loss=4.142]
# 128/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.20it/s, loss=1.699]
# [2021-01-10 13:43:27,544]
# 128/200 * Epoch 128 (_base): lr=0.0007 | momentum=0.9000
# 128/200 * Epoch 128 (train): loss=7.0539
# 128/200 * Epoch 128 (valid): loss=2.4893
# 129/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.94it/s, loss=3.645]
# 129/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.07it/s, loss=2.745]
# [2021-01-10 13:43:38,590]
# 129/200 * Epoch 129 (_base): lr=0.0007 | momentum=0.9000
# 129/200 * Epoch 129 (train): loss=7.0411
# 129/200 * Epoch 129 (valid): loss=4.0102
# 130/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.48it/s, loss=3.385]
# 130/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.30it/s, loss=2.433]
# [2021-01-10 13:43:49,269]
# 130/200 * Epoch 130 (_base): lr=0.0007 | momentum=0.9000
# 130/200 * Epoch 130 (train): loss=7.0441
# 130/200 * Epoch 130 (valid): loss=3.6785
# 131/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.71it/s, loss=3.322]
# 131/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.58it/s, loss=2.263]
# [2021-01-10 13:43:59,834]
# 131/200 * Epoch 131 (_base): lr=0.0007 | momentum=0.9000
# 131/200 * Epoch 131 (train): loss=7.1490
# 131/200 * Epoch 131 (valid): loss=4.3745
# 132/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.55it/s, loss=3.355]
# 132/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.62it/s, loss=1.719]
# [2021-01-10 13:44:10,455]
# 132/200 * Epoch 132 (_base): lr=0.0007 | momentum=0.9000
# 132/200 * Epoch 132 (train): loss=7.2143
# 132/200 * Epoch 132 (valid): loss=2.7237
# 133/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.93it/s, loss=3.393]
# 133/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.28it/s, loss=1.533]
# [2021-01-10 13:44:21,487]
# 133/200 * Epoch 133 (_base): lr=0.0007 | momentum=0.9000
# 133/200 * Epoch 133 (train): loss=7.3708
# 133/200 * Epoch 133 (valid): loss=3.3357
# 134/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.29it/s, loss=3.413]
# 134/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 43.94it/s, loss=1.565]
# [2021-01-10 13:44:32,345]
# 134/200 * Epoch 134 (_base): lr=0.0007 | momentum=0.9000
# 134/200 * Epoch 134 (train): loss=7.2065
# 134/200 * Epoch 134 (valid): loss=2.7044
# 135/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.04it/s, loss=3.897]
# 135/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.02it/s, loss=2.083]
# [2021-01-10 13:44:43,378]
# 135/200 * Epoch 135 (_base): lr=0.0007 | momentum=0.9000
# 135/200 * Epoch 135 (train): loss=7.0313
# 135/200 * Epoch 135 (valid): loss=3.7916
# 136/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.76it/s, loss=3.934]
# 136/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.14it/s, loss=2.285]
# [2021-01-10 13:44:54,472]
# 136/200 * Epoch 136 (_base): lr=0.0007 | momentum=0.9000
# 136/200 * Epoch 136 (train): loss=7.3160
# 136/200 * Epoch 136 (valid): loss=3.8288
# 137/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.84it/s, loss=3.684]
# 137/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.47it/s, loss=1.478]
# [2021-01-10 13:45:05,566]
# 137/200 * Epoch 137 (_base): lr=0.0007 | momentum=0.9000
# 137/200 * Epoch 137 (train): loss=7.2659
# 137/200 * Epoch 137 (valid): loss=2.9065
# 138/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.64it/s, loss=3.617]
# 138/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.83it/s, loss=2.855]
# [2021-01-10 13:45:16,155]
# 138/200 * Epoch 138 (_base): lr=0.0007 | momentum=0.9000
# 138/200 * Epoch 138 (train): loss=7.1270
# 138/200 * Epoch 138 (valid): loss=3.5513
# 139/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.23it/s, loss=3.438]
# 139/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.02it/s, loss=1.879]
# [2021-01-10 13:45:26,995]
# 139/200 * Epoch 139 (_base): lr=0.0007 | momentum=0.9000
# 139/200 * Epoch 139 (train): loss=6.9714
# 139/200 * Epoch 139 (valid): loss=3.2527
# 140/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.23it/s, loss=3.546]
# 140/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.58it/s, loss=2.501]
# [2021-01-10 13:45:37,803]
# 140/200 * Epoch 140 (_base): lr=0.0007 | momentum=0.9000
# 140/200 * Epoch 140 (train): loss=7.0821
# 140/200 * Epoch 140 (valid): loss=3.0662
# 141/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.57it/s, loss=3.913]
# 141/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.32it/s, loss=1.555]
# [2021-01-10 13:45:48,455]
# 141/200 * Epoch 141 (_base): lr=0.0007 | momentum=0.9000
# 141/200 * Epoch 141 (train): loss=6.8784
# 141/200 * Epoch 141 (valid): loss=2.3929
# 142/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.09it/s, loss=3.812]
# 142/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.93it/s, loss=2.803]
# [2021-01-10 13:45:59,356]
# 142/200 * Epoch 142 (_base): lr=0.0007 | momentum=0.9000
# 142/200 * Epoch 142 (train): loss=7.1579
# 142/200 * Epoch 142 (valid): loss=4.4166
# 143/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.74it/s, loss=3.367]
# 143/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.39it/s, loss=1.923]
# [2021-01-10 13:46:10,435]
# 143/200 * Epoch 143 (_base): lr=0.0007 | momentum=0.9000
# 143/200 * Epoch 143 (train): loss=7.1124
# 143/200 * Epoch 143 (valid): loss=2.7992
# 144/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.77it/s, loss=3.417]
# 144/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 37.88it/s, loss=1.911]
# [2021-01-10 13:46:21,605]
# 144/200 * Epoch 144 (_base): lr=0.0007 | momentum=0.9000
# 144/200 * Epoch 144 (train): loss=6.8660
# 144/200 * Epoch 144 (valid): loss=3.0630
# 145/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.93it/s, loss=3.413]
# 145/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.80it/s, loss=2.042]
# [2021-01-10 13:46:32,578]
# 145/200 * Epoch 145 (_base): lr=0.0007 | momentum=0.9000
# 145/200 * Epoch 145 (train): loss=7.1171
# 145/200 * Epoch 145 (valid): loss=3.2874
# 146/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.30it/s, loss=3.757]
# 146/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.22it/s, loss=1.712]
# [2021-01-10 13:46:43,347]
# 146/200 * Epoch 146 (_base): lr=0.0007 | momentum=0.9000
# 146/200 * Epoch 146 (train): loss=6.9217
# 146/200 * Epoch 146 (valid): loss=3.1432
# 147/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.71it/s, loss=3.695]
# 147/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.54it/s, loss=1.596]
# [2021-01-10 13:46:54,445]
# 147/200 * Epoch 147 (_base): lr=0.0007 | momentum=0.9000
# 147/200 * Epoch 147 (train): loss=6.9977
# 147/200 * Epoch 147 (valid): loss=2.8125
# 148/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.34it/s, loss=4.132]
# 148/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 38.34it/s, loss=1.965]
# [2021-01-10 13:47:05,269]
# 148/200 * Epoch 148 (_base): lr=0.0007 | momentum=0.9000
# 148/200 * Epoch 148 (train): loss=6.8663
# 148/200 * Epoch 148 (valid): loss=3.0532
# 149/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.05it/s, loss=3.531]
# 149/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.62it/s, loss=2.107]
# [2021-01-10 13:47:16,214]
# 149/200 * Epoch 149 (_base): lr=0.0007 | momentum=0.9000
# 149/200 * Epoch 149 (train): loss=6.9303
# 149/200 * Epoch 149 (valid): loss=3.0313
# 150/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.77it/s, loss=3.874]
# 150/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.98it/s, loss=2.185]
# [2021-01-10 13:47:27,294]
# 150/200 * Epoch 150 (_base): lr=0.0007 | momentum=0.9000
# 150/200 * Epoch 150 (train): loss=6.9269
# 150/200 * Epoch 150 (valid): loss=3.5710
# 151/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.16it/s, loss=3.713]
# 151/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.68it/s, loss=2.447]
# [2021-01-10 13:47:38,181]
# 151/200 * Epoch 151 (_base): lr=0.0007 | momentum=0.9000
# 151/200 * Epoch 151 (train): loss=6.9098
# 151/200 * Epoch 151 (valid): loss=3.6102
# 152/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.78it/s, loss=3.808]
# 152/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 47.28it/s, loss=2.501]
# [2021-01-10 13:47:49,248]
# 152/200 * Epoch 152 (_base): lr=0.0007 | momentum=0.9000
# 152/200 * Epoch 152 (train): loss=6.9218
# 152/200 * Epoch 152 (valid): loss=2.8139
# 153/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.50it/s, loss=3.276]
# 153/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.59it/s, loss=3.069]
# [2021-01-10 13:48:00,538]
# 153/200 * Epoch 153 (_base): lr=0.0007 | momentum=0.9000
# 153/200 * Epoch 153 (train): loss=7.2178
# 153/200 * Epoch 153 (valid): loss=4.8905
# 154/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.33it/s, loss=3.163]
# 154/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.63it/s, loss=1.719]
# [2021-01-10 13:48:11,331]
# 154/200 * Epoch 154 (_base): lr=0.0007 | momentum=0.9000
# 154/200 * Epoch 154 (train): loss=7.3863
# 154/200 * Epoch 154 (valid): loss=2.6395
# 155/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.01it/s, loss=3.713]
# 155/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.96it/s, loss=2.177]
# [2021-01-10 13:48:22,268]
# 155/200 * Epoch 155 (_base): lr=0.0007 | momentum=0.9000
# 155/200 * Epoch 155 (train): loss=6.9747
# 155/200 * Epoch 155 (valid): loss=3.0871
# 156/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.39it/s, loss=3.476]
# 156/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 48.33it/s, loss=2.061]
# [2021-01-10 13:48:33,091]
# 156/200 * Epoch 156 (_base): lr=0.0007 | momentum=0.9000
# 156/200 * Epoch 156 (train): loss=6.9392
# 156/200 * Epoch 156 (valid): loss=3.7655
# 157/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.79it/s, loss=3.578]
# 157/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.94it/s, loss=2.100]
# [2021-01-10 13:48:44,168]
# 157/200 * Epoch 157 (_base): lr=0.0007 | momentum=0.9000
# 157/200 * Epoch 157 (train): loss=6.8791
# 157/200 * Epoch 157 (valid): loss=3.1292
# 158/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.06it/s, loss=3.368]
# 158/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.83it/s, loss=2.000]
# [2021-01-10 13:48:55,092]
# 158/200 * Epoch 158 (_base): lr=0.0007 | momentum=0.9000
# 158/200 * Epoch 158 (train): loss=7.0212
# 158/200 * Epoch 158 (valid): loss=3.1438
# 159/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.51it/s, loss=3.295]
# 159/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 40.30it/s, loss=1.840]
# [2021-01-10 13:49:06,385]
# 159/200 * Epoch 159 (_base): lr=0.0007 | momentum=0.9000
# 159/200 * Epoch 159 (train): loss=6.8338
# 159/200 * Epoch 159 (valid): loss=3.0287
# 160/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.15it/s, loss=3.977]
# 160/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.93it/s, loss=2.234]
# [2021-01-10 13:49:17,232]
# 160/200 * Epoch 160 (_base): lr=0.0007 | momentum=0.9000
# 160/200 * Epoch 160 (train): loss=6.9235
# 160/200 * Epoch 160 (valid): loss=3.2418
# 161/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.14it/s, loss=3.380]
# 161/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.89it/s, loss=1.995]
# [2021-01-10 13:49:28,129]
# 161/200 * Epoch 161 (_base): lr=0.0007 | momentum=0.9000
# 161/200 * Epoch 161 (train): loss=6.9221
# 161/200 * Epoch 161 (valid): loss=3.3761
# 162/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.24it/s, loss=3.593]
# 162/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 43.14it/s, loss=2.113]
# [2021-01-10 13:49:38,959]
# 162/200 * Epoch 162 (_base): lr=0.0005 | momentum=0.9000
# 162/200 * Epoch 162 (train): loss=6.9524
# 162/200 * Epoch 162 (valid): loss=3.2479
# 163/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.30it/s, loss=3.386]
# 163/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.44it/s, loss=1.941]
# [2021-01-10 13:49:50,332]
# 163/200 * Epoch 163 (_base): lr=0.0005 | momentum=0.9000
# 163/200 * Epoch 163 (train): loss=6.7548
# 163/200 * Epoch 163 (valid): loss=2.9072
# 164/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.01it/s, loss=3.195]
# 164/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.90it/s, loss=1.642]
# [2021-01-10 13:50:01,344]
# 164/200 * Epoch 164 (_base): lr=0.0005 | momentum=0.9000
# 164/200 * Epoch 164 (train): loss=6.4994
# 164/200 * Epoch 164 (valid): loss=2.5777
# 165/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.14it/s, loss=3.603]
# 165/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.16it/s, loss=1.530]
# [2021-01-10 13:50:12,260]
# 165/200 * Epoch 165 (_base): lr=0.0005 | momentum=0.9000
# 165/200 * Epoch 165 (train): loss=6.5127
# 165/200 * Epoch 165 (valid): loss=2.5381
# 166/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.41it/s, loss=3.274]
# 166/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.76it/s, loss=1.895]
# [2021-01-10 13:50:23,625]
# 166/200 * Epoch 166 (_base): lr=0.0005 | momentum=0.9000
# 166/200 * Epoch 166 (train): loss=7.0173
# 166/200 * Epoch 166 (valid): loss=2.8922
# 167/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.25it/s, loss=3.410]
# 167/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.50it/s, loss=1.675]
# [2021-01-10 13:50:34,435]
# 167/200 * Epoch 167 (_base): lr=0.0005 | momentum=0.9000
# 167/200 * Epoch 167 (train): loss=6.5744
# 167/200 * Epoch 167 (valid): loss=2.5884
# 168/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.12it/s, loss=3.652]
# 168/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 38.92it/s, loss=1.768]
# [2021-01-10 13:50:45,380]
# 168/200 * Epoch 168 (_base): lr=0.0005 | momentum=0.9000
# 168/200 * Epoch 168 (train): loss=6.5741
# 168/200 * Epoch 168 (valid): loss=2.8963
# 169/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.77it/s, loss=3.270]
# 169/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.03it/s, loss=1.707]
# [2021-01-10 13:50:56,463]
# 169/200 * Epoch 169 (_base): lr=0.0005 | momentum=0.9000
# 169/200 * Epoch 169 (train): loss=6.5554
# 169/200 * Epoch 169 (valid): loss=2.9147
# 170/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.52it/s, loss=3.320]
# 170/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.24it/s, loss=1.485]
# [2021-01-10 13:51:07,173]
# 170/200 * Epoch 170 (_base): lr=0.0005 | momentum=0.9000
# 170/200 * Epoch 170 (train): loss=6.4862
# 170/200 * Epoch 170 (valid): loss=2.6734
# 171/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.36it/s, loss=3.580]
# 171/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.91it/s, loss=1.374]
# [2021-01-10 13:51:18,501]
# 171/200 * Epoch 171 (_base): lr=0.0005 | momentum=0.9000
# 171/200 * Epoch 171 (train): loss=6.5750
# 171/200 * Epoch 171 (valid): loss=2.9815
# 172/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.04it/s, loss=3.111]
# 172/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.50it/s, loss=1.181]
# [2021-01-10 13:51:29,418]
# 172/200 * Epoch 172 (_base): lr=0.0005 | momentum=0.9000
# 172/200 * Epoch 172 (train): loss=6.4911
# 172/200 * Epoch 172 (valid): loss=2.2502
# 173/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.18it/s, loss=3.338]
# 173/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.85it/s, loss=1.654]
# [2021-01-10 13:51:40,280]
# 173/200 * Epoch 173 (_base): lr=0.0005 | momentum=0.9000
# 173/200 * Epoch 173 (train): loss=6.4822
# 173/200 * Epoch 173 (valid): loss=2.6641
# 174/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.21it/s, loss=3.215]
# 174/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.06it/s, loss=1.686]
# [2021-01-10 13:51:51,140]
# 174/200 * Epoch 174 (_base): lr=0.0005 | momentum=0.9000
# 174/200 * Epoch 174 (train): loss=6.5244
# 174/200 * Epoch 174 (valid): loss=2.7404
# 175/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.43it/s, loss=3.760]
# 175/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.13it/s, loss=2.136]
# [2021-01-10 13:52:01,866]
# 175/200 * Epoch 175 (_base): lr=0.0005 | momentum=0.9000
# 175/200 * Epoch 175 (train): loss=6.5383
# 175/200 * Epoch 175 (valid): loss=3.5937
# 176/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.57it/s, loss=3.525]
# 176/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 43.13it/s, loss=1.940]
# [2021-01-10 13:52:13,106]
# 176/200 * Epoch 176 (_base): lr=0.0005 | momentum=0.9000
# 176/200 * Epoch 176 (train): loss=6.7591
# 176/200 * Epoch 176 (valid): loss=2.5776
# 177/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.95it/s, loss=3.127]
# 177/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.46it/s, loss=1.756]
# [2021-01-10 13:52:24,121]
# 177/200 * Epoch 177 (_base): lr=0.0005 | momentum=0.9000
# 177/200 * Epoch 177 (train): loss=6.4882
# 177/200 * Epoch 177 (valid): loss=2.7566
# 178/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.11it/s, loss=3.337]
# 178/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.70it/s, loss=2.091]
# [2021-01-10 13:52:35,073]
# 178/200 * Epoch 178 (_base): lr=0.0005 | momentum=0.9000
# 178/200 * Epoch 178 (train): loss=6.8320
# 178/200 * Epoch 178 (valid): loss=2.8062
# 179/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.14it/s, loss=3.824]
# 179/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.00it/s, loss=1.569]
# [2021-01-10 13:52:45,973]
# 179/200 * Epoch 179 (_base): lr=0.0005 | momentum=0.9000
# 179/200 * Epoch 179 (train): loss=6.5380
# 179/200 * Epoch 179 (valid): loss=2.6006
# 180/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.60it/s, loss=3.695]
# 180/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.95it/s, loss=2.436]
# [2021-01-10 13:52:57,161]
# 180/200 * Epoch 180 (_base): lr=0.0005 | momentum=0.9000
# 180/200 * Epoch 180 (train): loss=6.5095
# 180/200 * Epoch 180 (valid): loss=3.3190
# 181/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.39it/s, loss=3.046]
# 181/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 41.04it/s, loss=1.608]
# [2021-01-10 13:53:08,520]
# 181/200 * Epoch 181 (_base): lr=0.0005 | momentum=0.9000
# 181/200 * Epoch 181 (train): loss=6.4878
# 181/200 * Epoch 181 (valid): loss=2.6541
# 182/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.65it/s, loss=3.183]
# 182/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 40.19it/s, loss=1.307]
# [2021-01-10 13:53:19,726]
# 182/200 * Epoch 182 (_base): lr=0.0005 | momentum=0.9000
# 182/200 * Epoch 182 (train): loss=6.4530
# 182/200 * Epoch 182 (valid): loss=2.5073
# 183/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.38it/s, loss=3.290]
# 183/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.41it/s, loss=1.338]
# [2021-01-10 13:53:31,063]
# 183/200 * Epoch 183 (_base): lr=0.0005 | momentum=0.9000
# 183/200 * Epoch 183 (train): loss=6.4477
# 183/200 * Epoch 183 (valid): loss=2.4883
# 184/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.55it/s, loss=3.700]
# 184/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.51it/s, loss=1.547]
# [2021-01-10 13:53:42,280]
# 184/200 * Epoch 184 (_base): lr=0.0005 | momentum=0.9000
# 184/200 * Epoch 184 (train): loss=6.4434
# 184/200 * Epoch 184 (valid): loss=3.0678
# 185/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.80it/s, loss=3.238]
# 185/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.31it/s, loss=1.796]
# [2021-01-10 13:53:53,345]
# 185/200 * Epoch 185 (_base): lr=0.0005 | momentum=0.9000
# 185/200 * Epoch 185 (train): loss=6.4826
# 185/200 * Epoch 185 (valid): loss=2.9137
# 186/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.81it/s, loss=3.426]
# 186/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.18it/s, loss=1.728]
# [2021-01-10 13:54:04,420]
# 186/200 * Epoch 186 (_base): lr=0.0005 | momentum=0.9000
# 186/200 * Epoch 186 (train): loss=6.4636
# 186/200 * Epoch 186 (valid): loss=2.7971
# 187/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.58it/s, loss=3.170]
# 187/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.26it/s, loss=1.618]
# [2021-01-10 13:54:15,686]
# 187/200 * Epoch 187 (_base): lr=0.0005 | momentum=0.9000
# 187/200 * Epoch 187 (train): loss=6.4789
# 187/200 * Epoch 187 (valid): loss=2.6653
# 188/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.40it/s, loss=3.412]
# 188/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.51it/s, loss=1.753]
# [2021-01-10 13:54:26,996]
# 188/200 * Epoch 188 (_base): lr=0.0005 | momentum=0.9000
# 188/200 * Epoch 188 (train): loss=6.4016
# 188/200 * Epoch 188 (valid): loss=2.5187
# 189/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.99it/s, loss=3.446]
# 189/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.19it/s, loss=1.667]
# [2021-01-10 13:54:38,019]
# 189/200 * Epoch 189 (_base): lr=0.0005 | momentum=0.9000
# 189/200 * Epoch 189 (train): loss=6.4453
# 189/200 * Epoch 189 (valid): loss=2.5741
# 190/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.82it/s, loss=3.328]
# 190/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.68it/s, loss=1.609]
# [2021-01-10 13:54:49,137]
# 190/200 * Epoch 190 (_base): lr=0.0005 | momentum=0.9000
# 190/200 * Epoch 190 (train): loss=6.4587
# 190/200 * Epoch 190 (valid): loss=2.7199
# 191/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.27it/s, loss=3.418]
# 191/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.16it/s, loss=2.090]
# [2021-01-10 13:55:00,519]
# 191/200 * Epoch 191 (_base): lr=0.0005 | momentum=0.9000
# 191/200 * Epoch 191 (train): loss=6.4894
# 191/200 * Epoch 191 (valid): loss=3.0402
# 192/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.35it/s, loss=3.307]
# 192/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 42.23it/s, loss=1.461]
# [2021-01-10 13:55:11,885]
# 192/200 * Epoch 192 (_base): lr=0.0005 | momentum=0.9000
# 192/200 * Epoch 192 (train): loss=6.3727
# 192/200 * Epoch 192 (valid): loss=2.7014
# 193/200 * Epoch (train): 100% 188/188 [00:10<00:00, 18.13it/s, loss=3.151]
# 193/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 45.05it/s, loss=1.269]
# [2021-01-10 13:55:22,776]
# 193/200 * Epoch 193 (_base): lr=0.0003 | momentum=0.9000
# 193/200 * Epoch 193 (train): loss=6.3915
# 193/200 * Epoch 193 (valid): loss=2.6130
# 194/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.83it/s, loss=3.247]
# 194/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 43.29it/s, loss=1.428]
# [2021-01-10 13:55:33,848]
# 194/200 * Epoch 194 (_base): lr=0.0003 | momentum=0.9000
# 194/200 * Epoch 194 (train): loss=6.2529
# 194/200 * Epoch 194 (valid): loss=2.5767
# 195/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.51it/s, loss=2.974]
# 195/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 37.25it/s, loss=1.283]
# [2021-01-10 13:55:45,193]
# 195/200 * Epoch 195 (_base): lr=0.0003 | momentum=0.9000
# 195/200 * Epoch 195 (train): loss=6.2643
# 195/200 * Epoch 195 (valid): loss=2.5382
# 196/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.86it/s, loss=3.110]
# 196/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.53it/s, loss=1.335]
# [2021-01-10 13:55:56,286]
# 196/200 * Epoch 196 (_base): lr=0.0003 | momentum=0.9000
# 196/200 * Epoch 196 (train): loss=6.2564
# 196/200 * Epoch 196 (valid): loss=2.4573
# 197/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.49it/s, loss=3.250]
# 197/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 39.69it/s, loss=1.522]
# [2021-01-10 13:56:07,608]
# 197/200 * Epoch 197 (_base): lr=0.0003 | momentum=0.9000
# 197/200 * Epoch 197 (train): loss=6.2291
# 197/200 * Epoch 197 (valid): loss=2.8836
# 198/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.77it/s, loss=3.192]
# 198/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 44.58it/s, loss=1.210]
# [2021-01-10 13:56:18,707]
# 198/200 * Epoch 198 (_base): lr=0.0003 | momentum=0.9000
# 198/200 * Epoch 198 (train): loss=6.2358
# 198/200 * Epoch 198 (valid): loss=2.6072
# 199/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.43it/s, loss=2.909]
# 199/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 38.38it/s, loss=1.488]
# [2021-01-10 13:56:30,084]
# 199/200 * Epoch 199 (_base): lr=0.0003 | momentum=0.9000
# 199/200 * Epoch 199 (train): loss=6.2004
# 199/200 * Epoch 199 (valid): loss=2.8258
# 200/200 * Epoch (train): 100% 188/188 [00:10<00:00, 17.52it/s, loss=3.045]
# 200/200 * Epoch (valid): 100% 19/19 [00:00<00:00, 46.45it/s, loss=1.464]
# [2021-01-10 13:56:41,315]
# 200/200 * Epoch 200 (_base): lr=0.0003 | momentum=0.9000
# 200/200 * Epoch 200 (train): loss=6.2155
# 200/200 * Epoch 200 (valid): loss=2.6318
# Top best models:
# /content/drive/My Drive/robotics/logs/checkpoints/train.172.pth	2.2502
# => Loading checkpoint /content/drive/My Drive/robotics/logs/checkpoints/best_full.pth
# loaded state checkpoint /content/drive/My Drive/robotics/logs/checkpoints/best_full.pth (global epoch 172, epoch 172, stage train)

# %%
# !mkdir checkpoint
model = model.cpu()
# checkpoint_path = f'/content/drive/My Drive/robotics/{type(model).__name__}.pth'
checkpoint_path = f'{type(model).__name__}.pth'
torch.save(model.state_dict(), checkpoint_path)

# %%
checkpoint_path = f'{type(model).__name__}.pth'
model.load_state_dict(torch.load(checkpoint_path))
model.eval()
# Out:
# Model(
#   (block1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): AdaptiveMaxPool2d(output_size=(32, 32))
#   )
#   (block2): Sequential(
#     (0): Conv2d(16, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): AdaptiveMaxPool2d(output_size=(24, 24))
#   )
#   (block3): Sequential(
#     (0): Conv2d(24, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): AdaptiveMaxPool2d(output_size=(16, 16))
#   )
#   (block4): Sequential(
#     (0): Dropout2d(p=0.2, inplace=False)
#     (1): Conv2d(32, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): AdaptiveMaxPool2d(output_size=(8, 8))
#   )
#   (flat): Flatten(start_dim=2, end_dim=-1)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (linear1): Linear(in_features=48, out_features=100, bias=True)
#   (gru): GRU(64, 128, num_layers=4, batch_first=True, dropout=0.3, bidirectional=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (linear2): Linear(in_features=256, out_features=2, bias=True)
#   (tanh): Tanh()
# )

# %%
out_folder = 'results'
makedirs(out_folder, exist_ok=True)

model = model.cpu()
model.eval()


for num in range(len(functions)):
    func = functions[num]
    max_x = np.pi / 2
    linewidth = 4

    x, y = full_randomize(*generate_points(func, abs_value=max_x), seed=10, do_randomize=False)
    img = create_image(x, y, linewidth=linewidth)
    with torch.no_grad():
        tensor = VF.to_tensor(img).unsqueeze(0)
        points = model(tensor)[0]
    img = create_image(x, y, linewidth=linewidth, do_threshold=False)
    draw = ImageDraw.Draw(img)
    for i in range(points.shape[0]):
        pic_x, pic_y = points[i, 0] * orig_width / 2 + orig_width / 2, points[i, 1] * orig_height / 2 + orig_height / 2
        draw.ellipse([(pic_x - linewidth / 2, pic_y - linewidth / 2),
                      (pic_x + linewidth / 2, pic_y + linewidth / 2)],
                     fill='orange')

    img.save(path.join(out_folder, f'out{num}.png'))

# !zip -r results results/
# Out:
# updating: results/ (stored 0%)
# updating: results/out5.png (deflated 18%)
# updating: results/out6.png (deflated 14%)
# updating: results/out1.png (deflated 16%)
# updating: results/out0.png (deflated 16%)
# updating: results/out3.png (deflated 12%)
# updating: results/out2.png (deflated 18%)
# updating: results/out4.png (deflated 17%)
